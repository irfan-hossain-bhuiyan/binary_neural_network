# %%
import prelude as pl
import binray_transformer as bt
checkpoint=pl.load_training_checkpoint("./artifacts/binary_stable.pt")
model_discrete=checkpoint.model.clone()
model_discrete.discretize(0.5)
model_discrete.set_use_softmax(False)
x_all, y_all = bt.load_xor_dataset(dataset_path)
pl.testing(model_discrete,dataset=(x_all,y_all),threshold=0.9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import prelude as pl
#       2 import binray_transformer as bt
# ----> 3 checkpoint=pl.load_training_checkpoint("./artifacts/binary_stable.pt")
#       4 model_discrete=checkpoint.model.clone()
#       5 model_discrete.discretize(0.5)
#
# File ~/projects/binary_neural_network/binary_neural_network_transformer/prelude.py:66, in load_training_checkpoint(filepath, map_location)
#      65 def load_training_checkpoint(filepath: str | Path, map_location: str | torch.device | None = None) -> Checkpoint:
# ---> 66     checkpoint = torch.load(Path(filepath), map_location=map_location, weights_only=False)
#      67     if not isinstance(checkpoint, Checkpoint):
#      68         raise TypeError(f"Expected Checkpoint object, got {type(checkpoint)}")
#
# ...
